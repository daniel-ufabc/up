# %% [markdown]
# # Universidade Federal do ABC
#
# ## Bases Computacionais da Ciência -- 2018.Q2 -- Prova 2

# %% [markdown]
# ### Nome: <font color="red">Clique aqui duas vezes, coloque o seu nome e tecle SHIFT+ENTER</font>

# %% [markdown]
# ## Instruções
#
# * Deslique o seu celular.
# * Não é permitida a consulta a nenhum material *online* (Internet) nem *offline* (papéis, livros, etc.) e nem a colegas a menos que o professor dê permissão.
# * Salve seu trabalho frequentemente pelo menu _**File &raquo; Save and Checkpoint**_.

# %% [markdown]
# # Questão 1
#
# (1.0 ponto) Faça um programa que pergunte ao usuário por quatro números inteiros $a, b$ e $c$. Depois disso, seu programa deve calcular e mostrar para o usuário a área da superfície do paralelepípedo cujos lados medem $a, b$ e $c$.
#
# <img src="data:image/png;base64,..." />

# %% [markdown]
# # Questão 2
#
# (2.0 pontos) Faça um programa que pede por três números racionais $a, b$ e $c$ e que
#
# 1. diz se é possível formar um triângulo de lados $a, b$ e $c$;
# 2. em caso afirmativo, diz se o triângulo formado por lados  $a, b$ e $c$ é isósceles.

# %% [markdown]
# # Questão 3
#
# (3.0 pontos) Um número inteiro é chamado de _mediano_ se a média de seus dígitos é 5. Outro jeito de definir um número mediano seria dizer que é um número inteiro com $n$ dígitos tal que a soma dos seus dígitos é igual a $5n$. Por exemplo, 873255 é mediano. Faça um programa para contar quantos números medianos têm 6 dígitos (ou seja, conte todos os números medianos entre 100000 e 999999).

# %% [markdown]
# # Questão 4
#
# (3.0 pontos) Faça um programa para gerar o gráfico do smiley como na figura abaixo.
#
# <img width="600px" src="data:image/png;base64,..." />

# %% [markdown]
# # Questão 5
#
# (3.0 pontos) Um louco acha que consegue tirar exatamente 2 caras em 3 lançamentos de uma moeda honesta. Ele diz que paga R\$ 4.00 ao seu amigo se falhar. Seu amigo duvida que ele consiga, então diz que paga R\$ 10.00 se o louco conseguir. Suponha que esses dois apostadores repitam essa aposta 1000 vezes. Pergunta-se.
#
# 1. Alguém está em vantagem, mas quem? Será o louco ou seu amigo?
# 2. Qual o valor esperado aproximado de lucro da pessoa que tem a vantagem?

# %% [markdown]
# # Envie sua prova
#
# **Salve este notebook!**
#
# Execute a célula abaixo para enviar sua prova e receber o código de submissão!
#
# Depois entre em nosso site [2018.Q2.BCC](http://tidia4.ufabc.edu.br/portal/site/3f8c7fbe-cae4-4874-9329-11021062257f/) do Tidia4, em _**Atividades &raquo; Prova 2 (sua turma)**_ e cole **apenas** esse código e clique em _Submeter_.

# %%
import requests

try:
    if enviou != None:
        print('Você já enviou sua prova.')
        print('Seu código de submissão é:', enviou)
except NameError:
    nome = input("Digite seu nome completo: ")
    RA = input('Digite seu RA: ')
    print('Aguarde...')

    url = "http://177.104.60.13/up/bin/upload.py"
    fin = open('P2.ipynb', 'rb')
    files = {'file': fin, 'nome': nome, 'RA': RA, 'turma': 'NB7'}
    try:
        r = requests.post(url, files=files)
        enviou = r.text
        print('Copie e cole o código abaixo no tidia\n\n', enviou)
    finally:
        fin.close()
# Out:
# Digite seu nome completo: Daniel M. Martin
# Digite seu RA: 1760938
# Aguarde...
# Copie e cole o código abaixo no tidia
#
#
# npNki
